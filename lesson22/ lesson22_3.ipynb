# %%
import requests

url = 'https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json?page=0&size=1000'
response = requests.get(url)
if response.status_code == 200:
    data = response.json()

# %%
import pandas as pd

youbike_df = pd.DataFrame(data,
             columns=['sna', 'tot', 'sbi', 'sarea', 'ar', 'bemp'])
youbike_df.columns = ['站名','數量','可借','行政區','地址','可還']
youbike_df
# Out:
#                 站名  數量 可借  行政區                    地址  可還
# 0             興華公園  24  2  三重區       重陽路一段120巷/中華路2巷  20
# 1         三重國民運動中心  14  0  三重區         集美街/重新路四段184巷  14
# 2      捷運三重站(3號出口)  14  0  三重區            捷運路/捷運路37巷  13
# 3             後港公園  10  2  新莊區            建安街/建安街57巷   8
# 4           福營行政中心  20  3  新莊區            四維路17號-20號  16
# ..             ...  .. ..  ...                   ...  ..
# 352  四維國凱街口(立天下社區)  40  1  樹林區            四維路121號(旁)  38
# 353           頂崁公園  18  0  三重區   頂文一街頂文二街口(東南側公園人行道)  15
# 354    捷運三重站(1號出口)  14  0  三重區             捷運路36號(旁)  16
# 355  捷運徐匯中學站(1號出口)  12  0  蘆洲區  中山一路3號(捷運徐匯中學站1號出口旁)  11
# 356  捷運三民高中站(2號出口)  22  0  蘆洲區               復興路58號旁  19
#
# [357 rows x 6 columns]

# %%
youbike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站名      357 non-null    object
#  1   數量      357 non-null    object
#  2   可借      357 non-null    object
#  3   行政區     357 non-null    object
#  4   地址      357 non-null    object
#  5   可還      357 non-null    object
# dtypes: object(6)
# memory usage: 16.9+ KB

# %%
youbike_df[['數量','可借','可還']] = youbike_df[['數量','可借','可還']].astype(int)
youbike_df
# Out:
#                 站名  數量  可借  行政區                    地址  可還
# 0             興華公園  24   2  三重區       重陽路一段120巷/中華路2巷  20
# 1         三重國民運動中心  14   0  三重區         集美街/重新路四段184巷  14
# 2      捷運三重站(3號出口)  14   0  三重區            捷運路/捷運路37巷  13
# 3             後港公園  10   2  新莊區            建安街/建安街57巷   8
# 4           福營行政中心  20   3  新莊區            四維路17號-20號  16
# ..             ...  ..  ..  ...                   ...  ..
# 352  四維國凱街口(立天下社區)  40   1  樹林區            四維路121號(旁)  38
# 353           頂崁公園  18   0  三重區   頂文一街頂文二街口(東南側公園人行道)  15
# 354    捷運三重站(1號出口)  14   0  三重區             捷運路36號(旁)  16
# 355  捷運徐匯中學站(1號出口)  12   0  蘆洲區  中山一路3號(捷運徐匯中學站1號出口旁)  11
# 356  捷運三民高中站(2號出口)  22   0  蘆洲區               復興路58號旁  19
#
# [357 rows x 6 columns]

# %%
youbike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站名      357 non-null    object
#  1   數量      357 non-null    int64
#  2   可借      357 non-null    int64
#  3   行政區     357 non-null    object
#  4   地址      357 non-null    object
#  5   可還      357 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 16.9+ KB

# %%
youbike_df#dataFrame的groupby()
# Out:
#                 站名  數量  可借  行政區                    地址  可還
# 0             興華公園  24   2  三重區       重陽路一段120巷/中華路2巷  20
# 1         三重國民運動中心  14   0  三重區         集美街/重新路四段184巷  14
# 2      捷運三重站(3號出口)  14   0  三重區            捷運路/捷運路37巷  13
# 3             後港公園  10   2  新莊區            建安街/建安街57巷   8
# 4           福營行政中心  20   3  新莊區            四維路17號-20號  16
# ..             ...  ..  ..  ...                   ...  ..
# 352  四維國凱街口(立天下社區)  40   1  樹林區            四維路121號(旁)  38
# 353           頂崁公園  18   0  三重區   頂文一街頂文二街口(東南側公園人行道)  15
# 354    捷運三重站(1號出口)  14   0  三重區             捷運路36號(旁)  16
# 355  捷運徐匯中學站(1號出口)  12   0  蘆洲區  中山一路3號(捷運徐匯中學站1號出口旁)  11
# 356  捷運三民高中站(2號出口)  22   0  蘆洲區               復興路58號旁  19
#
# [357 rows x 6 columns]

# %%
#dataFrame的groupby()
youbike_df.groupby('行政區')[['數量','可借','可還']].sum()
# Out:
#        數量   可借    可還
# 行政區
# 三峽區   458  143   294
# 三重區   946   77   848
# 五股區   376   23   336
# 土城區   656   41   586
# 新莊區  1070   64   947
# 板橋區  1434   54  1299
# 樹林區   782   77   672
# 泰山區   222   11   143
# 淡水區    28    0    28
# 蘆洲區   452   36   395
# 鶯歌區   384  101   238

# %%
youbike_df.groupby('行政區')[['數量','可借','可還']].agg(['sum','max','min'])
# Out:
#        數量           可借            可還
#       sum max min  sum max min   sum max min
# 行政區
# 三峽區   458  46  10  143  25   0   294  45   0
# 三重區   946  44   8   77   6   0   848  43   4
# 五股區   376  32  10   23   6   0   336  30   9
# 土城區   656  50   8   41   5   0   586  48   5
# 新莊區  1070  64  10   64   5   0   947  60   6
# 板橋區  1434  60  10   54   3   0  1299  59   3
# 樹林區   782  40  10   77  19   0   672  38   7
# 泰山區   222  64  14   11   6   0   143  34   0
# 淡水區    28  28  28    0   0   0    28  28  28
# 蘆洲區   452  46  10   36  11   0   395  45   7
# 鶯歌區   384  40  10  101  17   0   238  35   6

# %%
youbike_df.groupby('行政區')[['數量','可借','可還']].agg([('總量','sum'),('最多','max'),('最少','min')])
# Out:
#        數量           可借           可還
#        總量  最多  最少   總量  最多 最少    總量  最多  最少
# 行政區
# 三峽區   458  46  10  143  25  0   294  45   0
# 三重區   946  44   8   77   6  0   848  43   4
# 五股區   376  32  10   23   6  0   336  30   9
# 土城區   656  50   8   41   5  0   586  48   5
# 新莊區  1070  64  10   64   5  0   947  60   6
# 板橋區  1434  60  10   54   3  0  1299  59   3
# 樹林區   782  40  10   77  19  0   672  38   7
# 泰山區   222  64  14   11   6  0   143  34   0
# 淡水區    28  28  28    0   0  0    28  28  28
# 蘆洲區   452  46  10   36  11  0   395  45   7
# 鶯歌區   384  40  10  101  17  0   238  35   6
