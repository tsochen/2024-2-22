# %%
import pandas as pd

df1 = pd.read_csv('各鄉鎮市區人口密度.csv')
df1.columns = df1.iloc[0]
df2 = df1.drop(index=0)
df3 = df2.dropna()
#print(df3)
df3[['年底人口數','人口密度']] = df3[['年底人口數','人口密度']].replace('… ','0')
df3
# Out:
# /tmp/ipykernel_24533/2428534646.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[['年底人口數','人口密度']] = df3[['年底人口數','人口密度']].replace('… ','0')
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島       0     2.38      0
# 370  106    南沙群島       0   0.5045      0
#
# [370 rows x 5 columns]

# %%
def slice_str(value:str)->str:
    if len(value) == 6:
        return value[:3]
    else:
        return value
    
def slice_str1(value:str)->str:
    if len(value) == 6:
        return value[-3:]
    else:
        return value

df3['縣市'] = df3['區域別'].map(slice_str)
df3['鄉鎮區'] = df3['區域別'].map(slice_str1)
# Out:
# /tmp/ipykernel_24533/4265169316.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['縣市'] = df3['區域別'].map(slice_str)
# /tmp/ipykernel_24533/4265169316.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['鄉鎮區'] = df3['區域別'].map(slice_str1)
