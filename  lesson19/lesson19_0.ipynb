# %%
import pandas as pd

df1 = pd.read_csv('各鄉鎮市區人口密度.csv')
df1.columns = df1.iloc[0]
df2 = df1.drop(index=0)
df3 = df2.dropna()
df4 = df3.drop(index=[369, 370])
df4
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 364  106  金門縣烏坵鄉     685      1.2    571
# 365  106  連江縣南竿鄉    7544     10.4    725
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
#
# [368 rows x 5 columns]

# %%
df4['縣市'] = df4['區域別'].str[:3]
df4['鄉鎮區'] = df4['區域別'].str[-3:]
#df4['區域別'].str.replace('連江縣','台灣')
df5 = df4.drop(columns='區域別')
df5
# Out:
# 0    統計年   年底人口數     土地面積   人口密度   縣市  鄉鎮區
# 1    106  551480  23.1373  23835  新北市  板橋區
# 2    106  387484   16.317  23747  新北市  三重區
# 3    106  413590   20.144  20532  新北市  中和區
# 4    106  222585   5.7138  38956  新北市  永和區
# 5    106  416524  19.7383  21102  新北市  新莊區
# ..   ...     ...      ...    ...  ...  ...
# 364  106     685      1.2    571  金門縣  烏坵鄉
# 365  106    7544     10.4    725  連江縣  南竿鄉
# 366  106    2360      9.9    238  連江縣  北竿鄉
# 367  106    1624      4.7    346  連江縣  莒光鄉
# 368  106    1352      3.8    356  連江縣  東引鄉
#
# [368 rows x 6 columns]

# %%
name = '連江縣東引鄉'
#str是sequence資料,可以使用subscript
print(name[:3])
print(name[-3:])
#str的實體方法
print(name.replace('連江縣','台灣'))
# Out:
# 連江縣
# 東引鄉
# 台灣東引鄉

# %%
series1 = pd.Series(pd.date_range(start='2023-01-01',end='2023-12-31',freq='D'))
#pd.date_range(start='2023-01-01',end='2023-12-31',freq='W')
display(series1.dt.year)
display(series1.dt.month)
display(series1.dt.day)
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 360    2023
# 361    2023
# 362    2023
# 363    2023
# 364    2023
# Length: 365, dtype: int32
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 360    12
# 361    12
# 362    12
# 363    12
# 364    12
# Length: 365, dtype: int32
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 360    27
# 361    28
# 362    29
# 363    30
# 364    31
# Length: 365, dtype: int32
