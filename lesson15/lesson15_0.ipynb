# %%
import matplotlib.pyplot as plt
import numpy as np

index = np.array([3, 4, 5, 6, 7])
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]
bin_width = 0.3

figure, axes = plt.subplots()
axes.bar(index,values1,width=bin_width,color='red')
axes.bar(index+bin_width,values2,width=bin_width,color='blue')
axes.bar(index-bin_width,values3,width=bin_width,color='green')
axes.get_xticks()
# Out:
# array([2., 3., 4., 5., 6., 7., 8.])

# %%
import matplotlib.pyplot as plt
import numpy as np

index = np.array([3, 4, 5, 6, 7])
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]
bin_width = 0.3

figure, axes = plt.subplots()
axes.bar(index,values1,width=bin_width,color='red')
axes.bar(index+bin_width,values2,width=bin_width,color='blue')
axes.bar(index-bin_width,values3,width=bin_width,color='green')
display(axes.get_xticks())
axes.set_xticks(index,labels=subject)

xmin, xmax, ymin, ymax = axes.axis()
xmin -= 0.2
xmax += 0.2
ymin += 1000
ymax += 1000
axes.axis([xmin, xmax, ymin, ymax])
display(axes.get_xticks())
# Out:
# array([2., 3., 4., 5., 6., 7., 8.])
# array([3, 4, 5, 6, 7])

# %%
import matplotlib.pyplot as plt
import numpy as np

index = np.array([3, 4, 5, 6, 7])
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]
bin_width = 0.3

figure, axes = plt.subplots()
axes.bar(index,values1,width=bin_width,color='red',label='value1')
axes.bar(index+bin_width,values2,width=bin_width,color='blue',label='value2')
axes.bar(index-bin_width,values3,width=bin_width,color='green',label='value3')
display(axes.get_xticks())
axes.set_xticks(index,labels=subject)

xmin, xmax, ymin, ymax = axes.axis()
xmin -= 0.2
xmax += 0.2
ymin += 1000
ymax += 1000
axes.axis([xmin, xmax, ymin, ymax])
axes.legend(loc='upper center',ncols=3)
display(axes.get_xticks())
# Out:
# array([2., 3., 4., 5., 6., 7., 8.])
# array([3, 4, 5, 6, 7])

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
font = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)

index = np.array([3, 4, 5, 6, 7])
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]
bin_width = 0.3

figure, axes = plt.subplots()
barContainer1 = axes.bar(index,values1,width=bin_width,color='red',label='value1')
barContainer2 = axes.bar(index+bin_width,values2,width=bin_width,color='blue',label='value2')
barContainer3 = axes.bar(index-bin_width,values3,width=bin_width,color='green',label='value3')
axes.set_xticks(index,labels=subject)
for index,rectangle in enumerate(barContainer1.patches):
    print(index,rectangle,type(rectangle))
    x = rectangle.get_x()
    y = rectangle.get_y()
    width = rectangle.get_width()
    height = rectangle.get_height()
    axes.annotate(str(values1[index]),xy=(x,height+30),fontproperties=font)

for index,rectangle in enumerate(barContainer2.patches):
    x = rectangle.get_x()
    y = rectangle.get_y()
    width = rectangle.get_width()
    height = rectangle.get_height()
    axes.annotate(str(values2[index]),xy=(x,height+30),fontproperties=font)

for index,rectangle in enumerate(barContainer3.patches):
    x = rectangle.get_x()
    y = rectangle.get_y()
    width = rectangle.get_width()
    height = rectangle.get_height()
    axes.annotate(str(values3[index]),xy=(x,height+30),fontproperties=font)


xmin, xmax, ymin, ymax = axes.axis()
xmin -= 0.2
xmax += 0.2
ymin += 1000
ymax += 1000
axes.axis([xmin, xmax, ymin, ymax])
axes.legend(loc='upper center',ncols=3)
# Out:
# 0 Rectangle(xy=(2.85, 0), width=0.3, height=5000, angle=0) <class 'matplotlib.patches.Rectangle'>
# 1 Rectangle(xy=(3.85, 0), width=0.3, height=6000, angle=0) <class 'matplotlib.patches.Rectangle'>
# 2 Rectangle(xy=(4.85, 0), width=0.3, height=7000, angle=0) <class 'matplotlib.patches.Rectangle'>
# 3 Rectangle(xy=(5.85, 0), width=0.3, height=8000, angle=0) <class 'matplotlib.patches.Rectangle'>
# 4 Rectangle(xy=(6.85, 0), width=0.3, height=9000, angle=0) <class 'matplotlib.patches.Rectangle'>

# %%
labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [20, 30, 45, 10]
colors =['yellow', 'green', 'red', 'blue']

figure, axes = plt.subplots()
axes.pie(values,labels=labels,colors=colors,explode=[0.2,0,0,0],startangle=180,shadow=True,autopct="%.2f%%")
plt.show()
